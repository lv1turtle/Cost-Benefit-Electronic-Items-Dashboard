# %%
import time

from preprocessor import Preprocessor
import pandas as pd

# %% [markdown]
# ### Intel Core CPU 이름 얻어내기
# - passmark 웹사이트에서 크롤링한 CPU 이름 목록 csv 파일로부터 Intel Core i3, i5, i7, i9 cpu 들을 추출하고,
# - 'i5-10400F' 와 같이 전처리한다.

# %%
def get_intel_core_cpu_names(file, target_column):
    """
    get intel core cpu name from all cpu name csv file
    :param all cpu name csv file from "passmark" web page:
    :param core, intel core shch as "i3, i5, i7, i9":
    :return intel core cpu names:
    """
    processed = get_i3_to_i9_intel_cpu(file, target_column)
    new = pd.DataFrame(columns=['cpu_name'])
    for idx, row in processed.iterrows():
        cpu_name = row[target_column]
        parsed_name = parse_intel_cpu_name(cpu_name)
        new.loc[len(new)] = parsed_name
    return new

# %% [markdown]
# - cpu 이름 목록 csv 파일로부터 Intel Core i3, i5, i7, i9 cpu 들을 추출

# %%
def get_i3_to_i9_intel_cpu(file, target_column):
    preprocessor = Preprocessor(file)
    processed = pd.DataFrame()
    for core in ['i3', 'i5', 'i7', 'i9']:
        processed = pd.concat(
            [
                processed,
                preprocessor.extract_rows_by_keyword_contains(keyword=core, target_column=target_column)
            ],
            ignore_index=True
        )
    return processed

# %% [markdown]
# - CPU 이름을 'i5-10400F' 와 같이 전처리한다.

# %%
def parse_intel_cpu_name(cpu_name):
    repeated = 'Intel Core'
    start_idx = cpu_name.find(repeated) + len(repeated)
    end_idx = cpu_name.find('@')
    if end_idx != -1:
        return cpu_name[start_idx:end_idx].strip()
    return cpu_name[start_idx:].strip()

# %% [markdown]
# ### Ryzen CPU 이름 얻어내기
# - passmark 웹사이트에서 크롤링한 CPU 이름 목록 csv 파일로부터 Ryzen 3, 5, 7, 9 cpu 들을 추출하고,
# - 'Ryzen 7 5800X' 와 같이 전처리한다.

# %%
def get_ryzen_cpu_names(file, target_column):
    """
    get ryzen cpu name from all cpu name csv file
    :param all cpu name csv file from "passmark" web page:
    :param core, intel core shch as "3, 5, 7, 9":
    :return ryzen core cpu names:
    """
    processed = get_ryzen3_to_9_amd_cpu(file, target_column)
    new = pd.DataFrame(columns=['cpu_name'])
    for idx, row in processed.iterrows():
        cpu_name = row[target_column]
        parsed_name = parse_ryzen_cpu_name(cpu_name)
        print(parsed_name)
        new.loc[len(new)] = parsed_name
    return new

# %% [markdown]
# - CPU 이름 목록 csv 파일로부터 Ryzen 3, 5, 7, 9 cpu 들을 추출

# %%
def get_ryzen3_to_9_amd_cpu(file, target_column):
    preprocessor = Preprocessor(file)
    processed = pd.DataFrame()
    for core in ['3', '5', '7', '9']:
        processed = pd.concat(
            [
                processed,
                preprocessor.extract_rows_by_keyword_contains(keyword=f"Ryzen {core}", target_column=target_column)
            ],
            ignore_index=True
        )
    return processed

# %% [markdown]
# - 'Ryzen 7 5800X' 와 같이 전처리

# %%
def parse_ryzen_cpu_name(cpu_name):
    repeated = 'AMD'
    start_idx = cpu_name.find(repeated) + len(repeated)
    return cpu_name[start_idx:].strip()

# %% [markdown]
# ### 전처리한 CPU 이름으로부터 키워드 추출하기
# - CPU 이름으로부터 핫딜 게시물을 필터링할 때 사용할 키워드들을 추출
# - 추출한 키워드는 cpu_name 옆에 keyword라는 컬럼으로 다음과 같이 추가 'Ryzen 5 3600, 3600'

# %%
def add_keyword_with_cpu_name(cpu_names, company):
    """
    :param cpu_nams: intel, ryzen cpu names:
    :param company: cpu manufacturing company(Intel, AMD):
    :return datafrmae including cpu name and keyword such as: (Ryzen 5 3600, 3600):
    """
    new = pd.DataFrame(columns=['cpu_name', 'keyword'])
    delimiter = ' '
    if company == 'AMD':
        delimiter = ' '
    elif company == 'Intel':
        delimiter = '-'

    for row in cpu_names.itertuples():
        name_words = row.cpu_name.split(delimiter)
        target_keyword = name_words[-1]
        if target_keyword == "Edition":
            target_keyword = name_words[2] if name_words[2] != "PRO" else name_words[3]
        new.loc[len(new)] = [row.cpu_name, target_keyword]
    new = new.sort_values(by=['keyword'], ignore_index=True)
    return new

# %% [markdown]
# ### CPU 키워드들을 통해 CPU 관련 핫딜 게시물 필터링하기
# - CPU 키워드들을 통해 CPU와 관련된 핫딜 게시물들을 필터링한다.
# - 필터링된 게시물 Row에는 연관된 CPU 제품의 이름이 product_name 컬럼으로 추가되어 저장

# %%
def get_posts_by_cpu_keyword(post_file, cpu_keywords_file):
    """
    cpu 키워드가 post의 title에 포함되어 있을 경우에만 post의 행을 가져옴
    또한, post의 행에 내용을 추가하여 다음의 컬럼들로 dataframe을 구성하고 csv로 저장
    post_title, product_name, price, shop_type, votes, views, created_at
    shop_type은 ''로 저장, 따로 전처리하여 적재예정
    """
    cpu_keywords = pd.read_csv(cpu_keywords_file)
    posts = pd.DataFrame(columns=[
        'post_title', 'product_name', 'price', 'shop_type',
        'votes', 'views', 'created_at'
    ])
    for row in cpu_keywords.itertuples():
        cpu_name = row.cpu_name
        cpu_keyword = row.keyword
        preprocessor = Preprocessor(post_file)
        processed = preprocessor.extract_rows_by_keyword_exactly(keyword=cpu_keyword, target_column='title',
                                                                 ignore_case_sensitive=True)
        for row in processed.itertuples():
            posts.loc[len(posts)] = [
                row.title, cpu_name, row.price, '',
                row.votes, row.views, row.created_at
            ]
        print(f"{cpu_name}: {cpu_keyword}")
    return posts

# %% [markdown]
# ### 불필요한 행 제거하기
# - 다른 부품에서 사용되는 키워드들을 통해 CPU와 연관 없는 행들을 제거

# %%
def delete_rows_except_cpu(cpu_post_file):
    """
    제외해야할 키워드를 통해 원치않는 행들을 제거하고,
    실제로는 판매 게시글이 없는 상품을 포함한 행들도 제거한 후 반환
    :param cpu_post_file:
    :return dataframe filtered:
    """
    keywords = [
        '마이크로닉스', '브라보텍', '기가', 'peerless', 'asus', '아수스',
        '노트북', '중고', 'rtx', '본체', '메모리', '케이스', '1660super',
        '앱코', '시소닉', '키크론', '장패드', '커세어', 'ddr', 'trident', 'Corsair',
        '8*2', 'rx570', '그래픽', '조립', 'B550', '1660ti', '에이서', 'beelink',
        '파빌리온', '데스크탑', '3060ti', '6600xt', '6700xt', '3070', '6600',
        '세트', '3060', 'msi', '3050', '6800 xt', '3080ti', '마이크론',
        'gigabyte', '빅터스', '4070', '4060', 'asrock', 'b650m', 'microsoft',
        'zotac', '3080', '7900xt', 'x670', 'asrock', 'z690', '샌디스크', 'x670e',
        '파이어쿠다', '마그네틱 케이블', 'evga', '6700 xt', '헤드폰', '마우스', '키보드',
        '태블릿', 'fsp', '1tb', 'gold', '골드', 'wd', '에너맥스', '870evo', '970 evo',
        '38gn 950', 'nvme', '980 pro', '980 프로', 'ssd', '870 evo', '삼성 980',
        '갤럭시', '클레브 CRAS X RGB 3600'
    ]
    keywords += [
        'RTX4090', 'RTX4080SUPER', 'RTX4070Ti', 'RTX4070SUPER', 'RTX4070',
        'RTX4060Ti', 'RTX4080', 'RTX4060', 'RTX3090', 'RTX3080Ti', 'RTX3080', 'RTX3070Ti',
        'RTX3070', 'RTX3060Ti', 'RTX3060', 'RTX3050', 'RTX2080Ti', 'RTX2080SUPER', 'RTX2060SUPER',
        'RTX2060', 'GTX1660Ti', 'GTX1660SUPER', 'GTX1660', 'GTX1650SUPER', 'GTX1650', 'GTX1630', 'GT1030',
        'GT730', 'GT710', 'GTX1050Ti', 'T1000', 'T600', 'T400', 'H100', 'L40S', 'A40', 'A30',
        'RTXA6000', 'RTXA5500', 'RTXA5000', 'RTXA4500', 'RTXA4000', 'RTXA2000', 'GTX760',
        'GTX750Ti', 'RTX6000', 'RTX5000', 'RTX4500', 'RTX4000', 'P400', 'P620', 'G210',
        'TeslaA100', 'P2000', '지포스GTX550Ti', 'GT610', 'RX7900XTX', 'RX7900XT',
        'RX7900GRE', 'RX7800XT', 'RX7700XT', 'RX7600XT', 'RX7600', 'RX6900XT',
        'RX6800XT', 'RX6800', 'RX6750XT', 'RX6700XT', 'RX6700', 'RX6650XT', 'RX6600XT',
        'RX6600', 'RX6500XT', 'RX6400', 'RX580', 'RX570', 'RX560', 'RX550', 'RX480',
        'W7900', 'W7800', 'W7700', 'W7600', 'W7500', 'W6900X', 'W6800X', 'W6800',
        'W6600', 'W5700', 'W5500', 'WX3200', 'WX3100', 'ARCA770', 'ARCA750',
        'ARCA580', 'ARCA380', 'ARCA310'
    ]
    keywords += [
        'RTX 4090', 'RTX 4080', 'RTX 4070',
        'RTX 4060', 'RTX 3090', 'RTX 3080',
        'RTX 3070', 'RTX 3060', 'RTX 3050', 'RTX 2080', 'RTX 2060',
        'GTX 1660', 'GTX 1650', 'GTX 1630', 'GT 1030',
        'GT 730', 'GT 710', 'GTX 1050', 'T 1000', 'T 600', 'T 400', 'H 100', 'L 40S', 'A 40', 'A 30',
        'RTX A6000', 'RTX A5500', 'RTX A5000', 'RTX A4500', 'RTX A4000', 'RTX A2000', 'GTX 760',
        'GTX 750', 'RTX 6000', 'RTX 5000', 'RTX 4500', 'RTX 4000', 'P 400', 'P 620', 'G 210',
        'Tesla A100', 'P 2000', 'GTX 550', 'GT 610', 'RX 7900',
        'RX 7800', 'RX 7700', 'RX 7600', 'RX 6900',
        'RX 6800', 'RX 6750', 'RX 6700', 'RX 6650', 'RX 6600',
        'RX 6500', 'RX 6400', 'RX 580', 'RX 570', 'RX 560', 'RX 550', 'RX 480',
        'W 7900', 'W 7800', 'W 7700', 'W 7600', 'W 7500', 'W 6900', 'W 6800',
        'W 6600', 'W 5700', 'W 5500', 'WX 3200', 'WX 3100', 'ARCA770', 'ARCA750',
        'ARCA580', 'ARCA380', 'ARCA310'
    ]
    df = pd.read_csv(cpu_post_file)
    for keyword in keywords:
        idx = df[df['post_title'].str.lower().str.contains(keyword.lower())].index
        df = df.drop(idx)
    products = [
        'i5-7600', 'i7-7700', 'i7-7800X', 'i7-7900X', 'i9-7900X', 'Ryzen 3 3300X',
        'Ryzen 3 PRO 1300', 'Ryzen 5 1400', 'Ryzen 5 Microsoft Surface Edition',
        'Ryzen 7 Extreme Edition', 'Ryzen 7 PRO 7840HS'
    ]
    for product in products:
        idx = df[df['product_name'] == product].index
        df = df.drop(idx)
    df = df.sort_values(by=['product_name'], ignore_index=True)
    return df

# %% [markdown]
# ### CPU 관련 게시물 추출하고 전처리하기
# - 위에서 정의한 함수들을 통해 CPU 이름을 전처리하여 키워드들을 얻어내고,
# - 얻어낸 키워드들을 통해 CPU 관련 핫딜 게시물들을 추출하고,
# - 불필요한 키워드를 포함한 행을 제거함으로써 CPU 제품 판매와 직접적으로 연관된 핫딜 게시물만 추출하여 csv 파일로 저장
# - 저장된 csv 파일은 다른 부품으로 게시물들을 전처리한 팀원들의 csv 파일과 Union하여 summary 테이블을 구성

# %%
def preprocess_cpu_posts():
    cpu_names_file = "../crawling/cpu_names/cpu_names_#i48.csv"
    intel_cpu_names = get_intel_core_cpu_names(cpu_names_file, 'cpu_name')
    ryzen_cpu_names = get_ryzen_cpu_names(cpu_names_file, 'cpu_name')
    intel_cpu_name_with_keyword = add_keyword_with_cpu_name(intel_cpu_names, 'Intel')
    ryzen_cpu_name_with_keyword = add_keyword_with_cpu_name(ryzen_cpu_names, 'AMD')
    all_cpu_name_with_keyword = pd.concat(
        [intel_cpu_name_with_keyword, ryzen_cpu_name_with_keyword],
        ignore_index=True
    )
    # 팀원들과 키워드 공유를 위해 저장
    all_cpu_name_with_keyword.to_csv("cpu_names/cpu_names_with_keyword.csv")
    print("Waiting for saving cpu name with keyword file")
    time.sleep(5)
    all_cpu_name_with_keyword_file = "cpu_names/cpu_names_with_keyword.csv"
    post_file = "../crawling/2021-2023.csv"
    # 1차 전처리
    cpu_posts = get_posts_by_cpu_keyword(post_file, all_cpu_name_with_keyword_file)
    # 1차 전처리 후, 백업을 위해 저장
    cpu_posts.to_csv("cpu_posts.csv")
    print("Waiting for saving cpu posts file")
    time.sleep(5)
    cpu_post_file = "cpu_posts.csv"
    # cpu와 관련 없는 게시물에 들어가는 키워드들로 필터링
    filtered = delete_rows_except_cpu(cpu_post_file)
    filtered.to_csv("posts_with_cpu.csv")
    print("Preprocessing cpu posts done")

if __name__ == "__main__":
    preprocess_cpu_posts()
# Out:
# Ryzen 3 PRO 5350G
# Ryzen 3 PRO 5350GE
# Ryzen 3 5300GE
# Ryzen 3 5300G
# Ryzen 3 3300X
# Ryzen 3 3100
# Ryzen 3 4300GE
# Ryzen 3 4100
# Ryzen 3 PRO 4350GE
# Ryzen 3 4300G
# Ryzen 3 PRO 4350G
# Ryzen 3 PRO 4355GE
# Ryzen 3 2300X
# Ryzen 3 3200GE
# Ryzen 3 PRO 1300
# Ryzen 3 3200G
# Ryzen 3 PRO 3200G
# Ryzen 3 1300X
# Ryzen 3 PRO 2200G
# Ryzen 3 2200G
# Ryzen 3 PRO 3200GE
# Ryzen 3 PRO 2200GE
# Ryzen 3 1200
# Ryzen 3 PRO 1200
# Ryzen 3 2200GE
# Ryzen 3 PRO 2100GE
# Ryzen 3 PRO 3300U
# Ryzen 3 PRO 2300U
# Ryzen 3 3300U
# Ryzen 3 2300U
# Ryzen 3 3250U
# Ryzen 3 3200U
# Ryzen 3 2200U
# Ryzen 3 3250C
# Ryzen 3 PRO 7330U
# Ryzen 3 5425U
# Ryzen 3 PRO 5475U
# Ryzen 3 PRO 4200G
# Ryzen 3 PRO 5450U
# Ryzen 3 5400U
# Ryzen 3 7330U
# Ryzen 3 PRO 4450U
# Ryzen 3 5300U
# Ryzen 3 4300U
# Ryzen 3 PRO 8300G
# Ryzen 3 PRO 8300GE
# Ryzen 3 PRO 7335U
# Ryzen 3 7320U
# Ryzen 5 5600X3D
# Ryzen 5 5600X
# Ryzen 5 PRO 5645
# Ryzen 5 5600
# Ryzen 5 PRO 5650G
# Ryzen 5 5500GT
# Ryzen 5 5600GT
# Ryzen 5 5600G
# Ryzen 5 5500
# Ryzen 5 5600GE
# Ryzen 5 3600XT
# Ryzen 5 PRO 5650GE
# Ryzen 5 3600X
# Ryzen 5 3600
# Ryzen 5 PRO 3600
# Ryzen 5 4400G
# Ryzen 5 PRO 4655G
# Ryzen 5 PRO 4650G
# Ryzen 5 4500
# Ryzen 5 4600G
# Ryzen 5 4600GE
# Ryzen 5 PRO 4650GE
# Ryzen 5 5560U
# Ryzen 5 7430U
# Ryzen 5 PRO 4655GE
# Ryzen 5 2600X
# Ryzen 5 PRO 2600
# Ryzen 5 2600
# Ryzen 5 3500X
# Ryzen 5 1600X
# Ryzen 5 3500
# Ryzen 5 1600
# Ryzen 5 PRO 1600
# Ryzen 5 2500X
# Ryzen 5 PRO 3350G
# Ryzen 5 3400G
# Ryzen 5 PRO 3400G
# Ryzen 5 PRO 1500
# Ryzen 5 1500X
# Ryzen 5 3350G
# Ryzen 5 3400GE
# Ryzen 5 2400G
# Ryzen 5 PRO 2400G
# Ryzen 5 PRO 3400GE
# Ryzen 5 1400
# Ryzen 5 PRO 2400GE
# Ryzen 5 2400GE
# Ryzen 5 2600H
# Ryzen 5 3550H
# Ryzen 5 Microsoft Surface Edition
# Ryzen 5 3580U
# Ryzen 5 PRO 3500U
# Ryzen 5 3500U
# Ryzen 5 3450U
# Ryzen 5 PRO 2500U
# Ryzen 5 2500U
# Ryzen 5 3500C
# Ryzen 5 5600H
# Ryzen 5 7530U
# Ryzen 5 5600U
# Ryzen 5 PRO 7530U
# Ryzen 5 5625U
# Ryzen 5 PRO 5650U
# Ryzen 5 PRO 5675U
# Ryzen 5 4600H
# Ryzen 5 4600HS
# Ryzen 5 4600U
# Ryzen 5 5500U
# Ryzen 5 PRO 4650U
# Ryzen 5 PRO 4500U
# Ryzen 5 5500H
# Ryzen 5 4500U
# Ryzen 5 7520U
# Ryzen 5 7600X
# Ryzen 5 PRO 7645
# Ryzen 5 7600
# Ryzen 5 7500F
# Ryzen 5 7645HX
# Ryzen 5 PRO 8600GE
# Ryzen 5 PRO 8600G
# Ryzen 5 8600G
# Ryzen 5 PRO 8500G
# Ryzen 5 8500G
# Ryzen 5 PRO 8500GE
# Ryzen 5 PRO 7640HS
# Ryzen 5 7640HS
# Ryzen 5 7640U
# Ryzen 5 8540U
# Ryzen 5 7540U
# Ryzen 5 PRO 6650H
# Ryzen 5 6600H
# Ryzen 5 7535HS
# Ryzen 5 6600HS Creator Edition
# Ryzen 5 PRO 7540U
# Ryzen 5 Pro 7535U
# Ryzen 5 6600U
# Ryzen 5 PRO 6650U
# Ryzen 5 7535U
# Ryzen 7 5800X3D
# Ryzen 7 5800X
# Ryzen 7 5700X
# Ryzen 7 5700X3D
# Ryzen 7 PRO 5845
# Ryzen 7 5800
# Ryzen 7 5700G
# Ryzen 7 PRO 5750G
# Ryzen 7 5700
# Ryzen 7 3800XT
# Ryzen 7 3800X
# Ryzen 7 PRO 3700
# Ryzen 7 3700X
# Ryzen 7 5700GE
# Ryzen 7 PRO 5750GE
# Ryzen 7 PRO 4750G
# Ryzen 7 4700G
# Ryzen 7 4700GE
# Ryzen 7 PRO 4700G
# Ryzen 7 PRO 4750GE
# Ryzen 7 5825U
# Ryzen 7 2700X
# Ryzen 7 PRO 2700X
# Ryzen 7 1800X
# Ryzen 7 2700
# Ryzen 7 1700X
# Ryzen 7 PRO 1700X
# Ryzen 7 PRO 2700
# Ryzen 7 1700
# Ryzen 7 2700E
# Ryzen 7 PRO 1700
# Ryzen 7 3750H
# Ryzen 7 2800H
# Ryzen 7 PRO 3700U
# Ryzen 7 PRO 2700U
# Ryzen 7 3700U
# Ryzen 7 3700C
# Ryzen 7 3780U
# Ryzen 7 2700U
# Ryzen 7 5800H
# Ryzen 7 5800HS
# Ryzen 7 7730U
# Ryzen 7 4800H
# Ryzen 7 5800U
# Ryzen 7 4800HS
# Ryzen 7 4980U Microsoft Surface Edition
# Ryzen 7 PRO 5850U
# Ryzen 7 Extreme Edition
# Ryzen 7 4800U
# Ryzen 7 PRO 5875U
# Ryzen 7 4850U Mobile
# Ryzen 7 5700U
# Ryzen 7 PRO 4750U
# Ryzen 7 4700U
# Ryzen 7 7700X
# Ryzen 7 PRO 7745
# Ryzen 7 7700
# Ryzen 7 7800X3D
# Ryzen 7 PRO 8700GE
# Ryzen 7 7745HX
# Ryzen 7 PRO 8700G
# Ryzen 7 8700G
# Ryzen 7 8845H
# Ryzen 7 7840HS
# Ryzen 7 8845HS
# Ryzen 7 7840H
# Ryzen 7 PRO 8840HS
# Ryzen 7 PRO 7840HS
# Ryzen 7 8840U
# Ryzen 7 8840HS
# Ryzen 7 7840S
# Ryzen 7 7735HS
# Ryzen 7 7735H
# Ryzen 7 6800H
# Ryzen 7 PRO 6850H
# Ryzen 7 6800HS
# Ryzen 7 7736U
# Ryzen 7 PRO 6850HS
# Ryzen 7 6800HS Creator Edition
# Ryzen 7 Pro 7735U
# Ryzen 7 7735U
# Ryzen 7 PRO 6850U
# Ryzen 9 5950X
# Ryzen 9 5900X
# Ryzen 9 3950X
# Ryzen 9 PRO 5945
# Ryzen 9 5900
# Ryzen 9 3900XT
# Ryzen 9 3900X
# Ryzen 9 PRO 3900
# Ryzen 9 3900
# Ryzen 9 5900H
# Ryzen 9 5980HX
# Ryzen 9 5900HX
# Ryzen 9 5900HS
# Ryzen 9 5980HS
# Ryzen 9 4900H
# Ryzen 9 4900HS
# Ryzen 9 7950X
# Ryzen 9 7950X3D
# Ryzen 9 7940HX
# Ryzen 9 7900X
# Ryzen 9 7900X3D
# Ryzen 9 7900
# Ryzen 9 PRO 7945
# Ryzen 9 8945H
# Ryzen 9 7940H
# Ryzen 9 7940HS
# Ryzen 9 8945HS
# Ryzen 9 PRO 7940HS
# Ryzen 9 6900HX
# Ryzen 9 6900HS
# Ryzen 9 PRO 6950HS
# Ryzen 9 PRO 6950H
# Ryzen 9 6900HS Creator Edition
# Ryzen 9 7945HX3D
# Ryzen 9 7945HX
# Ryzen 9 7845HX
# Waiting for saving cpu name with keyword file
# i3-10100: 10100
# i3-10100E: 10100E
# i3-10100F: 10100F
# i3-10100T: 10100T
# i3-10100TE: 10100TE
# i3-10100Y: 10100Y
# i3-10105: 10105
# i3-10105F: 10105F
# i3-10105T: 10105T
# i3-10110U: 10110U
# i5-10200H: 10200H
# i5-10210U: 10210U
# i3-10300: 10300
# i5-10300H: 10300H
# i3-10300T: 10300T
# i3-10305: 10305
# i3-10305T: 10305T
# i5-10310U: 10310U
# i3-10320: 10320
# i3-10325: 10325
# i5-10400: 10400
# i5-10400F: 10400F
# i5-10400H: 10400H
# i5-10400T: 10400T
# i5-10500: 10500
# i5-10500E: 10500E
# i5-10500H: 10500H
# i5-10500T: 10500T
# i5-10500TE: 10500TE
# i5-10505: 10505
# i7-10510U: 10510U
# i5-10600: 10600
# i5-10600K: 10600K
# i5-10600KF: 10600KF
# i5-10600T: 10600T
# i7-10610U: 10610U
# i7-10700: 10700
# i7-10700E: 10700E
# i7-10700F: 10700F
# i7-10700K: 10700K
# i7-10700KF: 10700KF
# Ryzen 7 4800H: 4800H
# Ryzen 7 4800HS: 4800HS
# Ryzen 7 4800U: 4800U
# Ryzen 9 4900H: 4900H
# Ryzen 9 4900HS: 4900HS
# Ryzen 7 4980U Microsoft Surface Edition: 4980U
# Ryzen 3 5300G: 5300G
# Ryzen 3 5300GE: 5300GE
# Ryzen 3 5300U: 5300U
# Ryzen 3 PRO 5350G: 5350G
# Ryzen 3 PRO 5350GE: 5350GE
# Ryzen 3 5400U: 5400U
# Ryzen 3 5425U: 5425U
# Ryzen 3 PRO 5450U: 5450U
# Ryzen 3 PRO 5475U: 5475U
# Ryzen 5 5500: 5500
# Ryzen 5 5500GT: 5500GT
# Ryzen 5 5500H: 5500H
# Ryzen 5 5500U: 5500U
# Ryzen 5 5560U: 5560U
# Ryzen 5 5600: 5600
# Ryzen 5 5600G: 5600G
# Ryzen 5 5600GE: 5600GE
# Ryzen 5 5600GT: 5600GT
# Ryzen 5 5600H: 5600H
# Ryzen 5 5600U: 5600U
# Ryzen 5 5600X: 5600X
# Ryzen 5 5600X3D: 5600X3D
# Ryzen 5 5625U: 5625U
# Ryzen 5 PRO 5645: 5645
# Ryzen 5 PRO 5650G: 5650G
# Ryzen 5 PRO 5650GE: 5650GE
# Ryzen 5 PRO 5650U: 5650U
# Ryzen 5 PRO 5675U: 5675U
# Ryzen 7 5700: 5700
# Ryzen 7 5700G: 5700G
# Ryzen 7 5700GE: 5700GE
# Ryzen 7 5700U: 5700U
# Ryzen 7 5700X: 5700X
# Ryzen 7 5700X3D: 5700X3D
# Ryzen 7 PRO 5750G: 5750G
# Ryzen 7 PRO 5750GE: 5750GE
# Ryzen 7 5800: 5800
# Ryzen 7 5800H: 5800H
# Ryzen 7 5800HS: 5800HS
# Ryzen 7 5800U: 5800U
# Ryzen 7 5800X: 5800X
# Ryzen 7 5800X3D: 5800X3D
# Ryzen 7 5825U: 5825U
# Ryzen 7 PRO 5845: 5845
# Ryzen 7 PRO 5850U: 5850U
# Ryzen 7 PRO 5875U: 5875U
# Ryzen 9 5900: 5900
# Ryzen 9 5900H: 5900H
# Ryzen 9 5900HS: 5900HS
# Ryzen 9 5900HX: 5900HX
# Ryzen 9 5900X: 5900X
# Ryzen 9 PRO 5945: 5945
# Ryzen 9 5950X: 5950X
# Ryzen 9 5980HS: 5980HS
# Ryzen 9 5980HX: 5980HX
# Ryzen 5 6600H: 6600H
# Ryzen 5 6600HS Creator Edition: 6600HS
# Ryzen 5 6600U: 6600U
# Ryzen 5 PRO 6650H: 6650H
# Ryzen 5 PRO 6650U: 6650U
# Ryzen 7 6800H: 6800H
# Ryzen 7 6800HS Creator Edition: 6800HS
# Ryzen 7 6800HS: 6800HS
# Ryzen 7 PRO 6850H: 6850H
# Ryzen 7 PRO 6850HS: 6850HS
# Ryzen 7 PRO 6850U: 6850U
# Ryzen 9 6900HS: 6900HS
# Ryzen 9 6900HS Creator Edition: 6900HS
# Ryzen 9 6900HX: 6900HX
